# %% [markdown]
# <a href="https://colab.research.google.com/github/kanokwan-hongsopa/PythonDataViz2026/blob/main/HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **673020487-7 กนกวรรณ หงษ์โสภา**

# %% [markdown]
# # HW4
# #### เขียน function ตัดเกรด โดยที่ input เป็นคะแนน(0-100) , output เป็นเกรด (F-A)
# #### วนลูปตัดเกรด input = [1,50,65,90,101,-5,49]

# %% [markdown]
# ##### กำหนด
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ  0  แต่น้อยกว่า 50 จะได้เกรด F
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ 50 แต่น้อยกว่า 55 จะได้เกรด D
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ 55 แต่น้อยกว่า 60 จะได้เกรด D+
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ 60 แต่น้อยกว่า 65 จะได้เกรด C
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ 65 แต่น้อยกว่า 70 จะได้เกรด C+
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ 70 แต่น้อยกว่า 75 จะได้เกรด B
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ 75 แต่น้อยกว่า 80 จะได้เกรด B+
#       ถ้าคะแนนอยู่ระหว่างมากกว่าหรือเท่ากับ 80  จะได้เกรด A
#       แต่ว่าค่าคะแนนจะต้องไม่ต่ำกว่า 0 และมากกว่า 100 ไม่งั้นจะเกิด error

# %%
def grade(scores):
    fesult = []
    for score in scores:
        if score < 0:
            fesult.append('error')
        elif score > 100:
            fesult.append('error')
        elif score >= 80:
            fesult.append('A')
        elif score >= 75:
            fesult.append('B+')
        elif score >= 70:
            fesult.append('B')
        elif score >= 65:
            fesult.append('C+')
        elif score >= 60:
            fesult.append('C')
        elif score >= 55:
            fesult.append('D+')
        elif score >= 50:
            fesult.append('D')
        else:
            fesult.append('F')
    return fesult

# %%
for score in [1,50,65,90,101,-5,49]:
    print(f'คะแนน {score} ได้เกรด {grade([score])[0]}')
# Out:
# คะแนน 1 ได้เกรด F
# คะแนน 50 ได้เกรด D
# คะแนน 65 ได้เกรด C+
# คะแนน 90 ได้เกรด A
# คะแนน 101 ได้เกรด error
# คะแนน -5 ได้เกรด error
# คะแนน 49 ได้เกรด F
